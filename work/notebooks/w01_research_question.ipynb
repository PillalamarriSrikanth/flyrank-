# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PillalamarriSrikanth/flyrank-/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# No code required for this introduction section.
print("Lane 2 Selected: Refresh / Content Opportunity Scoring")
# Out:
# Lane 2 Selected: Refresh / Content Opportunity Scoring

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Defining our binary target configuration
print("Target Variable: is_declining (1 = Needs Refresh, 0 = Healthy)")
# Out:
# Target Variable: is_declining (1 = Needs Refresh, 0 = Healthy)

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas as pd

# 1. Clone your personal fork repository into the Colab environment
repo_url = "https://github.com/PillalamarriSrikanth/flyrank-.git"
repo_name = "flyrank-"

if not os.path.exists(repo_name):
    print("cloning repository...")
    os.system(f"git clone {repo_url}")
else:
    print("Repository already cloned.")

# 2. Force Python to look inside the cloned repository folder for the CSV
csv_path = f"{repo_name}/data/raw/content_refresh_anonymized.csv"

if os.path.exists(csv_path):
    df = pd.read_csv(csv_path)
    print("\n✅ Success! File located and loaded cleanly.")

    # Print available columns to help debug the KeyError
    print("DataFrame columns:", df.columns.tolist())

    # Compute the 3 baseline metrics required for Section 3
    total_pages = len(df)
    # The 'KeyError: 'label'' indicates that neither 'is_declining' nor 'label' are present.
    # Please update 'is_declining' or 'label' below with an actual column name from the list printed above.
    declining_pages = df["is_declining"].sum() if "is_declining" in df.columns else df["label"].sum()
    pct_declining = (declining_pages / total_pages) * 100

    print(f"1. Total Dataset Volume: {total_pages:,} pages")
    print(f"2. Active Target Class: {declining_pages:,} decaying pages")
    print(f"3. Class Base Rate: {pct_declining:.2f}% of the dataset needs a refresh")
else:
    print(f"\n❌ Still missing. Checked path: {os.path.abspath(csv_path)}")
# Out:
# Repository already cloned.
#
# ✅ Success! File located and loaded cleanly.
# DataFrame columns: ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
# ---------------------------------------------------------------------------
# ...

# %%
import os
# Print everything inside the data/raw directory to double-check
print(os.listdir("../../data/raw/"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1167/574706295.py in <cell line: 0>()
#       1 import os
#       2 # Print everything inside the data/raw directory to double-check
# ----> 3 print(os.listdir("../../data/raw/"))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/raw/'

# %%
import pandas as pd

# Load the dataset directly from a public URL backup stream
url = "https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv"

try:
    df = pd.read_csv(url)
    print("✅ Success! Dataset downloaded and loaded cleanly.")

    # Compute the 3 baseline metrics required for Section 3
    total_pages = len(df)
    declining_pages = df["is_declining"].sum() if "is_declining" in df.columns else df["label"].sum()
    pct_declining = (declining_pages / total_pages) * 100

    print(f"1. Total Dataset Volume: {total_pages:,} pages")
    print(f"2. Active Target Class: {declining_pages:,} decaying pages")
    print(f"3. Class Base Rate: {pct_declining:.2f}% of the dataset needs a refresh")
except Exception as e:
    print(f"❌ Network error loading dataset: {e}")
# Out:
# ✅ Success! Dataset downloaded and loaded cleanly.
# ❌ Network error loading dataset: 'label'

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset from the cloned repository path
# The repository was cloned into /content/flyrank- by cell Aml9kEybtNug
csv_path = "/content/flyrank-/data/raw/content_refresh_anonymized.csv"

try:
    df = pd.read_csv(csv_path)
    print("✅ Success! Dataset loaded from cloned repository.")

    # Compute 3 real baseline metrics
    total_pages = len(df)

    # Based on the available columns from cell Aml9kEybtNug, 'trend_direction' seems to be the relevant column for declining pages.
    # Assuming 'down' in 'trend_direction' indicates a declining page.
    if "trend_direction" in df.columns:
        declining_pages = (df["trend_direction"] == "down").sum()
    else:
        print("Warning: 'trend_direction' column not found. Unable to compute declining pages. Please check your data.")
        declining_pages = 0 # Default to 0 if column is missing or handled differently

    pct_declining = (declining_pages / total_pages) * 100 if total_pages > 0 else 0

    print(f"1. Total Dataset Volume: {total_pages:,} pages")
    print(f"2. Active Target Class: {declining_pages:,} decaying pages (based on 'trend_direction' == 'down')")
    print(f"3. Class Base Rate: {pct_declining:.2f}% of the dataset needs a refresh")

except FileNotFoundError:
    print(f"❌ FileNotFoundError: Dataset not found at {csv_path}. Please ensure the repository is cloned and the path is correct.")
except KeyError as e:
    print(f"❌ KeyError: Missing expected column for baseline calculation: {e}. Available columns: {df.columns.tolist() if 'df' in locals() else 'DataFrame not loaded'}")
except Exception as e:
    print(f"❌ An unexpected error occurred: {e}")
# Out:
# ✅ Success! Dataset loaded from cloned repository.
# 1. Total Dataset Volume: 30,000 pages
# 2. Active Target Class: 16,262 decaying pages (based on 'trend_direction' == 'down')
# 3. Class Base Rate: 54.21% of the dataset needs a refresh

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Framework aligned with decision-support boundaries. Ready for modeling phase.")
# Out:
# Framework aligned with decision-support boundaries. Ready for modeling phase.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
